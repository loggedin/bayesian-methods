# %% [markdown]
# ## (a)

# %% [markdown]
# ### i.

# %% [markdown]
# $f(t \, | \, \theta)$ is a valid probability density function for a non-negative real-valued continuous random variable $t$ if and only if the following conditions hold:
#
# $$
# f(t \, | \, \theta) \geq 0 \quad \text{for all } t \geq 0;
# $$
#
# and
#
# $$
# \int_0^\infty f(t \, | \, \theta) \, dt = 1.
# $$

# %% [markdown]
# **Condition 1**
#
# Since
#
# $$
# \exp \left( -\alpha t - \frac {\beta} {2} t^2 \right) > 0
# $$
#
# for all $\alpha, \beta \in \mathbb{R}$, we have that
#
# $$
# f(t \, | \, \theta) \geq 0 \iff \alpha + \beta t \geq 0.
# $$
#
# Since $t \geq 0$,
#
# $$
# f(t \, | \, \theta) \geq 0 \iff \alpha, \beta \geq 0.
# $$

# %% [markdown]
# **Condition 2**
#
# $$
# \int_0^\infty f(t \, | \, \theta) \, dt = \int_0^\infty (\alpha + \beta t) \exp \left( -\alpha t - \frac {\beta} {2} t^2 \right) \, dt
# $$
#
# Let $u = \alpha t + \frac {\beta} {2} t^2$, then $\frac {du} {dt} = \alpha + \beta t$. Assuming that $\alpha, \beta \geq 0$ and that at least one is strictly positive,
#
# $$
# \int_0^\infty f(t \, | \, \theta) \, dt = \int_0^\infty \exp (-u) \, du
# = \left[ -\exp (-u) \right]_{0}^{\infty}
# = 1.
# $$

# %% [markdown]
# **Conclusion**
#
# $f(t \, | \, \theta)$ is a valid probability density function for a non-negative real-valued continuous random variable $t$ if and only if $\alpha, \beta \geq 0$ and at least one is strictly positive.

# %% [markdown]
# ### ii.

# %% [markdown]
# $$
# F(t \, | \, \theta) = \int_0^t f(s \, | \, \theta) \, ds
# = \int_0^t (\alpha + \beta s) \exp \left( -\alpha s - \frac {\beta} {2} s^2 \right) \, ds
# $$
#
# Let $u = \alpha s + \frac {\beta} {2} s^2$, then $\frac {du} {ds} = \alpha + \beta s$ and
#
# $$
# F(t \, | \, \theta) = \int_0^{\alpha t + \frac{\beta}{2} t^2} \exp \left( -u \right) \, du
# = \left[ \, -\exp (-u) \, \right]_{0}^{\alpha t + \frac{\beta}{2} t^2}
# = \left[ \, \exp (-u) \, \right]_{\alpha t + \frac{\beta}{2} t^2}^{0}
# = 1 - \exp \left( -\alpha t - \frac{\beta}{2} t^2 \right).
# $$

# %% [markdown]
# $$
# h ( t \, | \, \theta \, ) = \frac { f ( t \, | \, \theta ) } { 1 - F ( t \, | \, \theta ) }
# $$
#
# Substituting $f ( t \, | \, \theta )$ and $F ( t \, | \, \theta )$,
#
# $$
# h ( t \, | \, \theta \, ) = \frac {(\alpha + \beta t) \exp \left( -\alpha t - \frac {\beta} {2} t^2 \right)} {1 - \left( 1 - \exp \left( -\alpha t - \frac{\beta}{2} t^2 \right) \right)}.
# $$
#
# Simplifying, we get
#
# $$
# h ( t \, | \, \theta \, ) = \frac {(\alpha + \beta t) \exp \left( -\alpha t - \frac {\beta} {2} t^2 \right)} {\exp \left( -\alpha t - \frac{\beta}{2} t^2 \right)}
# = \alpha + \beta t,
# $$
#
# which is linear in $t$ for $t \geq 0$.

# %% [markdown]
# ### iii.

# %% [markdown]
# From Definition 4.3.1, a density $f( t \, | \, \theta )$ belongs to an exponential family if there are functions $g, h, \eta, T$ such that
#
# $$
# f( t \, | \, \theta ) = h(t) g(\theta) \exp \{ \eta(\theta)^T \cdot T(t) \}.
# $$
#
# Define $\eta(\theta)$ and $T(t)$ as
#
# $$
# \eta(\theta) = \begin{pmatrix}
# -\alpha \\
# -\frac{\beta}{2}
# \end{pmatrix}, \ T(t) = \begin{pmatrix}
# t \\
# t^2
# \end{pmatrix}
# $$
#
# then
#
# $$
# \eta(\theta)^T \cdot T(t) = \begin{pmatrix}
# -\alpha & -\frac{\beta}{2}
# \end{pmatrix} \cdot \begin{pmatrix}
# t \\
# t^2
# \end{pmatrix}
# = -\alpha t - \frac{\beta}{2}t^2.
# $$

# %% [markdown]
# Therefore, $f( t \, | \, \theta )$ corresponds to an exponential family distribution if
#
# $$
# \alpha + \beta t = h(t) g(\theta)
# $$
#
# $$
# \implies \alpha = 0 \quad \text{or} \quad \beta = 0.
# $$

# %% [markdown]
# ### iv.

# %% [markdown]
# $$
# F(t \, | \, \theta) = 1 - \exp \left( -\alpha t - \frac{\beta}{2} t^2 \right)
# $$
#
# Set $p = F(t \, | \, \theta)$ and solve for $t$.
#
# $$
# p = 1 - \exp \left( -\alpha t - \frac{\beta}{2} t^2 \right)
# $$
#
# $$
# \implies \exp \left( -\alpha t - \frac{\beta}{2} t^2 \right) = 1 - p
# $$
#
# $$
# \implies -\alpha t - \frac{\beta}{2} t^2 = \ln (1 - p)
# $$
#
# $$
# \implies \frac{\beta}{2} t^2 + \alpha t + \ln (1 - p) = 0
# $$

# %% [markdown]
# Applying the quadratic formula,
#
# $$
# t = \frac {-\alpha \pm \sqrt{\alpha^2 - 4 \left( \frac{\beta}{2} \right) \ln (1 - p)}} {2 \left( \frac{\beta}{2} \right)}
# = \frac {-\alpha \pm \sqrt{\alpha^2 - 2 \beta  \ln (1 - p)}} {\beta}.
# $$

# %% [markdown]
# Since $t \geq 0$, take the positive root. Note from (a) i. that $\alpha \geq 0$.
#
# $$
# t = \frac {-\alpha + \sqrt{\alpha^2 - 2 \beta  \ln (1 - p)}} {\beta}
# $$
#
# $$
# \implies F ^ {-1} (p \, | \, \theta) = \frac {-\alpha + \sqrt{\alpha^2 - 2 \beta  \ln (1 - p)}} {\beta}
# $$

# %% [markdown]
# ### v.

# %% [markdown]
# Since $\alpha=1, \beta=4$,
#
# $$
# F(t \, | \, \theta) = 1 - \exp \left( - t - 2 t^2 \right).
# $$
#
# From Exercise 1.6, if $l ( \hat{t}, t ) = | \hat{t} - t |$ then the Bayes estimator $\hat{t}$ is the median.
#
# $$
# F(\hat{t} \, | \, \theta) = \frac{1}{2}
# $$
#
# $$
# \implies 1 - \exp \left( - \hat{t} - 2 \hat{t}^2 \right) = \frac{1}{2}
# $$
#
# $$
# \implies \exp \left( - \hat{t} - 2 \hat{t}^2 \right) = \frac{1}{2}
# $$
#
# $$
# \implies - \hat{t} - 2 \hat{t}^2 = \ln \left( \frac{1}{2} \right)
# $$
#
# $$
# \implies 2 \hat{t}^2 + \hat{t} + \ln \left( \frac{1}{2} \right) = 0
# $$

# %% [markdown]
# Applying the quadratic formula,
#
# $$
# \hat{t} = \frac { -1 \pm \sqrt{1^2 - 4 (2) \ln \left( \frac{1}{2} \right)} } { 2 (2) }
# = \frac { -1 \pm \sqrt{1 - 8 \ln \left( \frac{1}{2} \right)} } { 4 }
# = \frac { -1 \pm \sqrt{1 + 8 \ln \left( 2 \right)} } { 4 }.
# $$

# %% [markdown]
# Since $t \geq 0$, take the positive root.
#
# $$
# \hat{t} = \frac { -1 + \sqrt{1 + 8 \ln \left( 2 \right)} } { 4 }
# $$

# %% [markdown]
# ## (b)

# %% [markdown]
# ### i.

# %% [markdown]
# Since $x_i$ are independent,
#
# $$
# p ( \pmb{x} \, | \, t ) = \prod_{i=1}^{n} p(x_i \, | \, t).
# $$
#
# Since $x_i \sim \text{Uniform}[0, t]$,
#
# $$
# p(x_i \, | \, t) = \frac{1}{t} \mathbb{1}_{[0, t]}(x_i).
# $$
#
# Therefore,
#
# $$
# p ( \pmb{x} \, | \, t ) = \frac{1}{t^n} \mathbb{1}_{[0, t]^n}(\pmb{x}).
# $$

# %% [markdown]
# This is equivalent to
#
# $$
# p ( \pmb{x} \, | \, t ) = \frac{1}{t^n} \mathbb{1}_{[0, t]}(x_{(n)}).
# $$

# %% [markdown]
# ### ii.

# %% [markdown]
# Since $t \geq x_{(n)}$, the likelihood function is
#
# $$
# L ( t ) = \frac{1}{t^n} \mathbb{1}_{[x_{(n)}, \infty)}(t).
# $$
#
# So $L ( t ) > 0$ for all $t \in [x_{(n)}, \infty)$.
#
# Furthermore,
#
# $$
# \frac{dL}{dt} = -\frac{n}{t^{n+1}} \mathbb{1}_{[x_{(n)}, \infty)}(t).
# $$
#
# So $L ( t )$ is a decreasing function for all $t \in [x_{(n)}, \infty)$.
#
# Therefore, the maximum likelihood estimator of $t$ is $x_{(n)}$.

# %% [markdown]
# ### iii.

# %% [markdown]
# From Equation 4.2,
#
# $$
# \pi (t) \propto p ( \pmb{x} \, | \, t ) f ( t ).
# $$
#
# From (b) i.,
#
# $$
# p ( \pmb{x} \, | \, t ) = \frac{1}{t^n} \mathbb{1}_{[x_{(n)}, \infty)}(t).
# $$
#
# From the question, prior beliefs about $t$ are described by a linear hazard rate distribution with $\alpha=0, \beta=1$. That is,
#
# $$
# f ( t ) = t \exp \left( -\frac {1} {2} t^2 \right).
# $$
#
# Therefore,
#
# $$
# \begin{array}{rcl}
# \pi (t) & \propto & \frac{1}{t^n} \mathbb{1}_{[x_{(n)}, \infty)}(t) t \exp \left( -\frac {1} {2} t^2 \right) \\\\
# & = & t^{1-n} \exp \left( -\frac {1} {2} t^2 \right) \mathbb{1}_{[x_{(n)}, \infty)}(t).
# \end{array}
# $$

# %% [markdown]
# ### iv.

# %%
import numpy as np
import matplotlib.pyplot as plt

def pi(t, n, x_max):
    '''Compute the (unnormalised) posterior density.'''
    if t >= x_max:
        return t**(1-n) * np.exp(-0.5 * t**2)
    else:
        return 0

def q(t_prime, t, delta):
    '''Compute the proposal density.'''
    if t - delta <= t_prime <= t + delta:
        return 1 / (2 * delta)
    else:
        return 0

def metropolis_hastings(n, x_max, delta, M, burn_in):
    '''Perform Metropolis-Hastings MCMC sampling.'''
    samples = np.zeros(M)
    accept_count = 0
    # Step 1: Initialise the Markov chain at a sensible starting value
    # I have chosen the maximum likelihood estimator of t
    t_current = x_max
    
    # Step 2: for i = 1, ..., M
    for i in range(M):
        # Step 3: Draw t_prime from Uniform(t_current - delta, t_current + delta)
        t_prime = np.random.uniform(t_current - delta, t_current + delta)
        # Step 4: Draw u from Uniform(0, 1)
        u = np.random.uniform(0, 1)
        # Compute alpha(t_current, t_prime)
        pi_current = pi(t_current, n, x_max)
        pi_prime = pi(t_prime, n, x_max)
        # NOTE: I am aware that in this example q_current_given_prime and q_prime_given_current will always be the same and therefore cancel each other out but including for completeness 
        q_current_given_prime = q(t_current, t_prime, delta)
        q_prime_given_current = q(t_prime, t_current, delta)
        # Handle the case when pi_current = 0
        if pi_current == 0:
            alpha = 1
        else:
            alpha = min(1, (pi_prime * q_current_given_prime) / (pi_current * q_prime_given_current))
        
        # Steps 5-8: Accept or reject t_prime
        if u < alpha:
            samples[i] = t_prime
            t_current = t_prime
            accept_count += 1
        else:
            samples[i] = t_current
    
    # Discard burn-in samples
    samples = samples[burn_in:]
    acceptance_rate = accept_count / M
    
    return samples, acceptance_rate

# %% [markdown]
# ## (c)

# %% [markdown]
# ### i.

# %%
x = [1.338, 0.567, 0.086, 0.035, 1.708, 1.917, 1.274, 1.532, 1.142, 1.964]
n = len(x)
x_max = max(x)
deltas = [0.05, 0.5, 5, 50]
M = 100000
burn_in = 1000

# %%
for delta in deltas:
    samples, acceptance_rate = metropolis_hastings(n, x_max, delta, M, burn_in)
    
    print(f'delta={delta}:')
    print(f'Acceptance rate: {acceptance_rate * 100:.2f}%\n')
# Out:
# delta=0.05:
# Acceptance rate: 85.32%
#
# delta=0.5:
# Acceptance rate: 30.86%
#
# delta=5:
# Acceptance rate: 3.23%
#
# delta=50:
# Acceptance rate: 0.29%

# %% [markdown]
# ### ii.

# %%
for delta in deltas:
    samples, acceptance_rate = metropolis_hastings(n, x_max, delta, M, burn_in)
    
    plt.plot(samples, label=f'delta={delta}')
    plt.ylabel('Sampled t')
    plt.xlabel('Iteration')
    plt.title('Trace Plot')
    plt.legend()
    plt.show()

# %% [markdown]
# As $\delta$ increases, the traces become smoother. This is because the corresponding acceptance rates get lower.
#
# The range of sampled $t$ values is smaller for the two extreme values of $\delta$: $\delta=0.05$ and $\delta=50$.

# %% [markdown]
# ## (d)

# %% [markdown]
# ### i.

# %% [markdown]
# $\delta=0.5$ yielded a post-burn-in acceptance rate closest to 25%.

# %%
def prior_density(t):
    '''Compute the prior probability density function.'''
    return t * np.exp(-0.5 * t**2)

# Plot the prior probability density function
t_values = np.linspace(0, 5, 1000)
prior_values = prior_density(t_values)
plt.plot(t_values, prior_values, color='r', label='Prior Density')

delta = 0.5
samples, acceptance_rate = metropolis_hastings(n, x_max, delta, M, burn_in)
# Plot a histogram of the samples as an estimate of the posterior density
plt.hist(samples, bins=10, density=True, alpha=0.5, label='Posterior Density')

# Mark the observed data values from x on the horizontal axis
plt.scatter(x, np.zeros_like(x), color='black', label='Observed Data')

plt.ylabel('Density')
plt.xlabel('t')
plt.title('Prior and Posterior Densities with Observed Data')
plt.legend()
plt.show()

# %% [markdown]
# ### ii.

# %%
# Calculate the 2.5-th and 97.5-th percentiles of samples
lower_bound = np.percentile(samples, 2.5)
upper_bound = np.percentile(samples, 97.5)
print('95% posterior credible interval for t:', [lower_bound, upper_bound])
# Out:
# 95% posterior credible interval for t: [1.9678991413348568, 2.5655804088301366]

# %% [markdown]
# ### iii.

# %%
# Take the median (as per Exercise 1.6) of samples
posterior_median = np.median(samples)
print('Estimated t assuming the absolute value loss function:', posterior_median)
# Out:
# Estimated t assuming the absolute value loss function: 2.0749769615330833

# %% [markdown]
# ## (e)

# %% [markdown]
# ### i.

# %%
# Calculate the naive Monte Carlo estimate from samples
posterior_probability = np.mean(samples >= 4)
print('Naive Monte Carlo estimate of the posterior probability that t >= 4:', posterior_probability)
# Out:
# Naive Monte Carlo estimate of the posterior probability that t >= 4: 0.0

# %% [markdown]
# This is clearly inaccurate: the probability must be non-zero, just very small. This could be remedied by taking a larger sample.

# %% [markdown]
# ### ii.

# %% [markdown]
# The only change that we need to make to the Metropolis Hastings sampling code is
#
# $$
# \pi (t) \propto t^{1-n} \exp \left( -\frac {1} {2} t^2 \right) \mathbb{1}_{[4, \infty)}(t).
# $$

# %%
def pi(t, n, x_max):
    '''Compute the (unnormalised) posterior density, given that t >= 4.'''
    if t >= 4:
        return t**(1-n) * np.exp(-0.5 * t**2)
    else:
        return 0

samples, acceptance_rate = metropolis_hastings(n, x_max, delta, M, burn_in)

# %%
# Calculate the Monte Carlo estimate of the posterior conditional expectation
posterior_conditional_expectation = np.mean(samples)
print('Monte Carlo Estimate of E(t | t >= 4):', posterior_conditional_expectation)
# Out:
# Monte Carlo Estimate of E(t | t >= 4): 4.155736021706835
